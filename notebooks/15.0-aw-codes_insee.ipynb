# %%
import pandas as pd
dep = pd.read_csv('../src/streamlit/streamlit_library/code_insee_departement_2023.csv')
com = pd.read_csv('../src/streamlit/streamlit_library/code_insee_commune_2023.csv')

# %%
dep.head(2)
# Out:
#   DEP  REG CHEFLIEU  TNCC    NCC NCCENR LIBELLE
# 0  01   84    01053     5    AIN    Ain     Ain
# 1  02   32    02408     5  AISNE  Aisne   Aisne

# %%
com.head(2)
# Out:
#   TYPECOM    COM   REG DEP CTCD  ARR  TNCC                    NCC  \
# 0     COM  01001  84.0  01  01D  012     5  ABERGEMENT CLEMENCIAT
# 1     COM  01002  84.0  01  01D  011     5    ABERGEMENT DE VAREY
#
#                   NCCENR                  LIBELLE   CAN  COMPARENT
# 0  Abergement-Clémenciat  L'Abergement-Clémenciat  0108        NaN
# 1    Abergement-de-Varey    L'Abergement-de-Varey  0101        NaN

# %% [markdown]
# ## Departement

# %%
dep[['DEP', 'LIBELLE']].head(2)
# Out:
#   DEP LIBELLE
# 0  01     Ain
# 1  02   Aisne

# %%
dict_dep = dep[['DEP', 'LIBELLE']].to_dict(orient='records')

# %%
dict_dep
# Out:
# [{'DEP': '01', 'LIBELLE': 'Ain'},
#  {'DEP': '02', 'LIBELLE': 'Aisne'},
#  {'DEP': '03', 'LIBELLE': 'Allier'},
#  {'DEP': '04', 'LIBELLE': 'Alpes-de-Haute-Provence'},
#  {'DEP': '05', 'LIBELLE': 'Hautes-Alpes'},
#  {'DEP': '06', 'LIBELLE': 'Alpes-Maritimes'},
#  {'DEP': '07', 'LIBELLE': 'Ardèche'},
#  {'DEP': '08', 'LIBELLE': 'Ardennes'},
#  {'DEP': '09', 'LIBELLE': 'Ariège'},
#  {'DEP': '10', 'LIBELLE': 'Aube'},
#  {'DEP': '11', 'LIBELLE': 'Aude'},
#  {'DEP': '12', 'LIBELLE': 'Aveyron'},
#  {'DEP': '13', 'LIBELLE': 'Bouches-du-Rhône'},
#  {'DEP': '14', 'LIBELLE': 'Calvados'},
#  {'DEP': '15', 'LIBELLE': 'Cantal'},
#  {'DEP': '16', 'LIBELLE': 'Charente'},
#  {'DEP': '17', 'LIBELLE': 'Charente-Maritime'},
#  {'DEP': '18', 'LIBELLE': 'Cher'},
#  {'DEP': '19', 'LIBELLE': 'Corrèze'},
#  {'DEP': '21', 'LIBELLE': "Côte-d'Or"},
#  {'DEP': '22', 'LIBELLE': "Côtes-d'Armor"},
#  {'DEP': '23', 'LIBELLE': 'Creuse'},
#  {'DEP': '24', 'LIBELLE': 'Dordogne'},
#  {'DEP': '25', 'LIBELLE': 'Doubs'},
# ...

# %%
deps= {dep['DEP']: dep['LIBELLE'] for dep in dict_dep}
deps
# Out:
# {'01': 'Ain',
#  '02': 'Aisne',
#  '03': 'Allier',
#  '04': 'Alpes-de-Haute-Provence',
#  '05': 'Hautes-Alpes',
#  '06': 'Alpes-Maritimes',
#  '07': 'Ardèche',
#  '08': 'Ardennes',
#  '09': 'Ariège',
#  '10': 'Aube',
#  '11': 'Aude',
#  '12': 'Aveyron',
#  '13': 'Bouches-du-Rhône',
#  '14': 'Calvados',
#  '15': 'Cantal',
#  '16': 'Charente',
#  '17': 'Charente-Maritime',
#  '18': 'Cher',
#  '19': 'Corrèze',
#  '21': "Côte-d'Or",
#  '22': "Côtes-d'Armor",
#  '23': 'Creuse',
#  '24': 'Dordogne',
#  '25': 'Doubs',
#  '26': 'Drôme',
#  '27': 'Eure',
#  '28': 'Eure-et-Loir',
#  '29': 'Finistère',
#  '2A': 'Corse-du-Sud',
#  '2B': 'Haute-Corse',
#  '30': 'Gard',
#  '31': 'Haute-Garonne',
#  '32': 'Gers',
#  '33': 'Gironde',
#  '34': 'Hérault',
#  '35': 'Ille-et-Vilaine',
#  '36': 'Indre',
#  '37': 'Indre-et-Loire',
#  '38': 'Isère',
#  '39': 'Jura',
#  '40': 'Landes',
#  '41': 'Loir-et-Cher',
#  '42': 'Loire',
#  '43': 'Haute-Loire',
#  '44': 'Loire-Atlantique',
#  '45': 'Loiret',
# ...

# %%
deps['201'] = deps['2A']
deps['202'] = deps['2B']

# %%
deps
# Out:
# {'01': 'Ain',
#  '02': 'Aisne',
#  '03': 'Allier',
#  '04': 'Alpes-de-Haute-Provence',
#  '05': 'Hautes-Alpes',
#  '06': 'Alpes-Maritimes',
#  '07': 'Ardèche',
#  '08': 'Ardennes',
#  '09': 'Ariège',
#  '10': 'Aube',
#  '11': 'Aude',
#  '12': 'Aveyron',
#  '13': 'Bouches-du-Rhône',
#  '14': 'Calvados',
#  '15': 'Cantal',
#  '16': 'Charente',
#  '17': 'Charente-Maritime',
#  '18': 'Cher',
#  '19': 'Corrèze',
#  '21': "Côte-d'Or",
#  '22': "Côtes-d'Armor",
#  '23': 'Creuse',
#  '24': 'Dordogne',
#  '25': 'Doubs',
#  '26': 'Drôme',
#  '27': 'Eure',
#  '28': 'Eure-et-Loir',
#  '29': 'Finistère',
#  '2A': 'Corse-du-Sud',
#  '2B': 'Haute-Corse',
#  '30': 'Gard',
#  '31': 'Haute-Garonne',
#  '32': 'Gers',
#  '33': 'Gironde',
#  '34': 'Hérault',
#  '35': 'Ille-et-Vilaine',
#  '36': 'Indre',
#  '37': 'Indre-et-Loire',
#  '38': 'Isère',
#  '39': 'Jura',
#  '40': 'Landes',
#  '41': 'Loir-et-Cher',
#  '42': 'Loire',
#  '43': 'Haute-Loire',
#  '44': 'Loire-Atlantique',
#  '45': 'Loiret',
# ...

# %%
for key in deps:
    deps[key] = key + " - " + deps[key]

# %%
deps
# Out:
# {'01': '01 - Ain',
#  '02': '02 - Aisne',
#  '03': '03 - Allier',
#  '04': '04 - Alpes-de-Haute-Provence',
#  '05': '05 - Hautes-Alpes',
#  '06': '06 - Alpes-Maritimes',
#  '07': '07 - Ardèche',
#  '08': '08 - Ardennes',
#  '09': '09 - Ariège',
#  '10': '10 - Aube',
#  '11': '11 - Aude',
#  '12': '12 - Aveyron',
#  '13': '13 - Bouches-du-Rhône',
#  '14': '14 - Calvados',
#  '15': '15 - Cantal',
#  '16': '16 - Charente',
#  '17': '17 - Charente-Maritime',
#  '18': '18 - Cher',
#  '19': '19 - Corrèze',
#  '21': "21 - Côte-d'Or",
#  '22': "22 - Côtes-d'Armor",
#  '23': '23 - Creuse',
#  '24': '24 - Dordogne',
#  '25': '25 - Doubs',
#  '26': '26 - Drôme',
#  '27': '27 - Eure',
#  '28': '28 - Eure-et-Loir',
#  '29': '29 - Finistère',
#  '2A': '2A - Corse-du-Sud',
#  '2B': '2B - Haute-Corse',
#  '30': '30 - Gard',
#  '31': '31 - Haute-Garonne',
#  '32': '32 - Gers',
#  '33': '33 - Gironde',
#  '34': '34 - Hérault',
#  '35': '35 - Ille-et-Vilaine',
#  '36': '36 - Indre',
# ...

# %% [markdown]
# ## Communes:

# %%
dict_com = com[['COM', 'LIBELLE']].to_dict(orient='records')

# %%
coms = {com['COM']: com['LIBELLE'] for com in dict_com}

# %%
coms
# Out:
# {'01001': "L'Abergement-Clémenciat",
#  '01002': "L'Abergement-de-Varey",
#  '01004': 'Ambérieu-en-Bugey',
#  '01005': 'Ambérieux-en-Dombes',
#  '01006': 'Ambléon',
#  '01007': 'Ambronay',
#  '01008': 'Ambutrix',
#  '01009': 'Andert-et-Condon',
#  '01010': 'Anglefort',
#  '01011': 'Apremont',
#  '01012': 'Aranc',
#  '01013': 'Arandas',
#  '01014': 'Arbent',
#  '01015': 'Arbignieu',
#  '01016': 'Arbigny',
#  '01017': 'Argis',
#  '01019': 'Armix',
#  '01021': 'Ars-sur-Formans',
#  '01022': 'Artemare',
#  '01023': 'Asnières-sur-Saône',
#  '01024': 'Attignat',
#  '01025': 'Bâgé-la-Ville',
#  '01026': 'Bâgé-le-Châtel',
#  '01027': 'Balan',
#  '01028': 'Baneins',
#  '01029': 'Beaupont',
#  '01030': 'Beauregard',
#  '01031': 'Bellignat',
#  '01032': 'Béligneux',
#  '01033': 'Bellegarde-sur-Valserine',
#  '01034': 'Belley',
#  '01035': 'Belleydoux',
#  '01036': 'Belmont-Luthézieu',
#  '01037': 'Bénonces',
#  '01038': 'Bény',
#  '01039': 'Béon',
#  '01040': 'Béréziat',
#  '01041': 'Bettant',
# ...

# %%
for key in coms:
    coms[key] = key + " - " + coms[key]
coms
# Out:
# {'01001': "01001 - L'Abergement-Clémenciat",
#  '01002': "01002 - L'Abergement-de-Varey",
#  '01004': '01004 - Ambérieu-en-Bugey',
#  '01005': '01005 - Ambérieux-en-Dombes',
#  '01006': '01006 - Ambléon',
#  '01007': '01007 - Ambronay',
#  '01008': '01008 - Ambutrix',
#  '01009': '01009 - Andert-et-Condon',
#  '01010': '01010 - Anglefort',
#  '01011': '01011 - Apremont',
#  '01012': '01012 - Aranc',
#  '01013': '01013 - Arandas',
#  '01014': '01014 - Arbent',
#  '01015': '01015 - Arbignieu',
#  '01016': '01016 - Arbigny',
#  '01017': '01017 - Argis',
#  '01019': '01019 - Armix',
#  '01021': '01021 - Ars-sur-Formans',
#  '01022': '01022 - Artemare',
#  '01023': '01023 - Asnières-sur-Saône',
#  '01024': '01024 - Attignat',
#  '01025': '01025 - Bâgé-la-Ville',
#  '01026': '01026 - Bâgé-le-Châtel',
#  '01027': '01027 - Balan',
#  '01028': '01028 - Baneins',
#  '01029': '01029 - Beaupont',
#  '01030': '01030 - Beauregard',
#  '01031': '01031 - Bellignat',
#  '01032': '01032 - Béligneux',
# ...
